# %% [markdown]
# In order to democratize data analysis in UN Volunteers, this set of notebooks show learning excersises and real case scenarios with Volunteers data.
#
# ##### We use Python 3 with different open source libraries for
#
# - data manipulation
# - data preparation
# - data structures
# - data analysis + data modeling
# - data visualization
# - statistics
#
# This notebook explores data of UN Volunteers from 2008 to 2019.

# %%
#Load libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Loading the data in NumPy is inefficient because it has different data types. Use pandas instead

# %%
#csvnp = np.genfromtxt ('https://raw.githubusercontent.com/United-Nations-Volunteers/Volunteers-Data/master/data/UNVolunteersData.csv', delimiter=",",usecols=np.arange(0,13),dtype=None, encoding=None)
df = pd.read_csv('https://raw.githubusercontent.com/United-Nations-Volunteers/Volunteers-Data/master/data/UNVolunteersData.csv')

# %%
print(df)
# Out:
#        Volunteer Id  ... Assignment Duration
# 0            144444  ...                48.0
# 1            214119  ...                72.0
# 2            229197  ...                14.0
# 3            280251  ...                39.0
# 4            300774  ...                24.0
# ...             ...  ...                 ...
# 36789        250080  ...                13.0
# 36790        250134  ...                 6.0
# 36791        250977  ...                 6.0
# 36792        251682  ...                 6.0
# 36793        252033  ...                 6.0
#
# [36794 rows x 13 columns]

# %%
df['Assignment Duration']
# Out:
# 0        48.0
# 1        72.0
# 2        14.0
# 3        39.0
# 4        24.0
#          ...
# 36789    13.0
# 36790     6.0
# 36791     6.0
# 36792     6.0
# 36793     6.0
# Name: Assignment Duration, Length: 36794, dtype: float64

# %%
volArray = np.array(df['Assignment Duration'])

# %%
type(volArray)
# Out:
# numpy.ndarray

# %%
type(volArray[0])
# Out:
# numpy.float64

# %%
volArrayInts = volArray.astype(np.int32)

# %%
np.median(volArrayInts)
# Out:
# 20.0
