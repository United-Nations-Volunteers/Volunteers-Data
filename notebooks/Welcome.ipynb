# %% [markdown]
# In order to democratize data analysis in UN Volunteers, this set of notebooks show learning excersises and real case scenarios with Volunteers data.
#
# ##### They use Python 3 with different open source libraries for
# - data manipulation
# - data preparation
# - data structures
# - data analysis + data modeling
# - data visualization
# - statistics
#
# This notebook uses numpy library to explore data of UN Volunteers Data 2008 to 2019.
#
# First of all, we load the python library.

# %%
#Load numpy library
import numpy as np

# %% [markdown]
# Data of UN Volunteers is available in our Github repo. We load the csv file using the genfromtxt method of numpy library

# %%
csv = np.genfromtxt ('https://raw.githubusercontent.com/United-Nations-Volunteers/Volunteers-Data/master/data/UNVolunteersData.csv', delimiter=",",usecols=np.arange(0,13),dtype=None, encoding=None)

# %%
#Check first row as example
csv[0]

# %%
volunteers = np.array(csv)
type(volunteers)
volunteers.shape
volunteers[0,0]
#Get Durations Column
durations_str = volunteers[:,12]
#Remove Header
durations_str = durations_str[1:]
durations = durations_str.astype(np.int32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b51870ec7f92> in <module>
# ----> 1 volunteers = np.array(csv)
#       2 type(volunteers)
#       3 volunteers.shape
#       4 volunteers[0,0]
#
# NameError: name 'np' is not defined
